# %%
import requests
from bs4 import BeautifulSoup
import os
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import nltk
import time
nltk.downloader.download('vader_lexicon')

def complete():
  tickers = ['HEXO']
  actuallinks = []
  datetime = []
  newsstory = []
  header = []
  url = 'https://finance.yahoo.com/quote/'
  for x in tickers:
    finance_url = url + x

    response = requests.get(finance_url)

    soup = BeautifulSoup(response.text, "lxml")


    links = [soup.select('#quoteNewsStream-0-Stream > ul > li:nth-of-type({}) a'.format(i))[0]['href'] for i in range(4,10)]

    for f in range(6):
      url = 'https://news.yahoo.com/' + links[f]
      response = requests.get(url)

      soup = BeautifulSoup(response.text)
      news = soup.find('div', attrs={'class': 'caas-body'}).text
      date = soup.find('time').text
      headline = soup.find('h1').text 
      datetime.append(date)
      header.append(headline)
      newsstory.append([x, news])


  vader = SentimentIntensityAnalyzer()  
  new_words = {
        'boom' : 3.0,
        'new' : 1.0,
        'fee' : -4.0,
        'fees' : -4.0,
        'rejected' : -3.0,
        'bullish' : 4.0,
        'bearish' : -4.0,
        'jeopardized' : -4.0,
        'recalculate' : -4.0,
        'testify' : -4.0,
        'questionable' : -4.0,
        'impeded' : -4.0,
        'exacerbate' :  -4.0,
        'overstatement' : -4.0,
        'slander' : -4.0,
        'nonperforming' : -4.0,
        'unfounded' : -4.0,
        'worst' : -4.0, 
        'illicit' : -4.0,
        'renegotiate' : -3.5,
        'manipulate' : -3.0,
        'disturbing' : -3.0,
        'circumvent' : -3.0,
        'prejudiced' : -3.0,
        'apparently' : -3.0,
        'frivolour' : -3.0,
        'reject' : -3.0,
        'protested' : -3.0,
        'rejects' : -3.0,
        'downsized' : -3.0,
        'grievance' : -3.0,
        'refile' : -3.0,
        'dissenting' : -2.5,
        'forclosed' : -2.0,
        'gratuitous' : -2.0,
        'unpredicted' : -2.0,
        'misapplication' : -2.0,
        'closeout' : -2.0,
        'collaborates' : -2.0,
        'oblige' : -2.0,
        'dissenters' : -2.0,
        'forego' : -2.0,
        'writs' : -2.0,
        'pledgors' : -2.0,
        'precipitated' : -2.0,
        'idled' : -1.5,
        'suggests' : -1.0,
        'bailee' : -1.0,
        'friendly' : -1.0,
        'arbitral' : -1.0,
        'breakthroughs' : -1.0,
        'favoring' : -1.0,
        'certiorari' : -1.0,
        'persists' : -1.0,
        'adjournments' : -1.0,
        'ignoring' : -1.0,
        'recalculate' : -1.0,
        'unmatched' : 4.0,
        'outperform' : 4.0,
        'voided' : 4.0,
        'confident' : 4.0,
        'rewarded' : 4.0,
        'prosperity' : 4.0,
        'discrepancy' : 4.0,
        'rectification' : 4.0,
        'critically' : 4.0,
        'frofeitable' : 4.0,
        'arbitrary' : 4.0,
        'turmoil' : 4.0,
        'imbalance' : 3.5,
        'progresses' : 3.0,
        'antecedent' : 3.0,
        'overcharged' : 3.0,
        'duress' : 3.0,
        'manipulation' : 3.0,
        'distressed' : 3.0,
        'dissolutions' : 3.0,
        'hazard' : 3.0,
        'expropriation' : 3.0,
        'understate' : 3.0,
        'unfit' : 3.0,
        'pleadings' : 3.0,
        'investigated' : 2.5,
        'sometime' : 2.0,
        'encroachment' : 2.0,
        'misstate' : 2.0,
        'mutandis' : 2.0,
        'defraud' : 2.0,
        'undefined' : 2.0,
        'delisting' : 2.0,
        'forfeits' : 2.0,
        'uncovers' : 2.0,
        'malpractice' : 2.0,
        'presumes' : 2.0,
        'grantors' : 2.0,
        'collapsing' : 1.5,
        'falsely' : 1.0,
        'unsound' : 1.0,
        'rejections' : 1.0,
        'whereabouts' : 1.0,
        'damaging' : 1.0,
        'reassignment' : 1.0,
        'distracting' : 1.0,
        'disapproved' : 1.0,
        'stagnant' : 1.0,
        'predeceases' : 1.0,
        'unsafe' : 1.0
    }
  columns = ['ticker', 'news'] 
  newsscore = pd.DataFrame(newsstory, columns = columns) 
  scores = newsscore['news'].apply(vader.polarity_scores).tolist()
  scores_df = pd.DataFrame(scores)
  newsscore = newsscore.join(scores_df, rsuffix='_right')
  newsscore['Date Time'] = datetime
  newsscore['Headlines'] = header
  pd.set_option('display.max_columns', None)
  NewsDocument = open('newsDocument.txt', 'w')
  print(newsscore, file = NewsDocument)
  NewsDocument.close()
  t = 180
  countdown(int(t))
def countdown(t):
  while t:
    mins, secs = divmod(t, 60)
    timer = '{:02d}:{:02d}'.format(mins, secs)
    print(timer, end="\r")
    time.sleep(1)
    t -= 1
    complete()
complete()
# Out:
# /usr/local/lib/python3.7/dist-packages/nltk/twitter/__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn("The twython library has not been installed. "
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-761f1b0c31e0> in <module>()
#     171     t -= 1
#     172     complete()
# --> 173 complete()
#
# <ipython-input-1-761f1b0c31e0> in complete()
#     162   NewsDocument.close()
#     163   t = 180
# --> 164   countdown(int(t))
#     165 def countdown(t):
#     166   while t:
#
# <ipython-input-1-761f1b0c31e0> in countdown(t)
#     170     time.sleep(1)
#     171     t -= 1
# --> 172     complete()
#     173 complete()
#
# <ipython-input-1-761f1b0c31e0> in complete()
# ...
